# %% [markdown]
# # Assignment 6: Machine Translation (English ↔ Hindi)

# %%
# !pip install transformers sentencepiece
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (4.49.0)
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.1-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: filelock in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from transformers) (0.33.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.12.2)
# Requirement already satisfied: colorama in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from requests->transformers) (2024.2.2)
# Downloading sentencepiece-0.2.1-cp312-cp312-win_amd64.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 12.6 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.2.1
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from transformers import MarianMTModel, MarianTokenizer

model_name = 'Helsinki-NLP/opus-mt-en-hi'
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)

text = 'This is a simple machine translation system.'
inputs = tokenizer(text, return_tensors='pt', padding=True)
translated = model.generate(**inputs)
print(tokenizer.decode(translated[0], skip_special_tokens=True))
# Out:
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# C:\Users\Prachi Shedge\AppData\Roaming\Python\Python312\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Prachi Shedge\.cache\huggingface\hub\models--Helsinki-NLP--opus-mt-en-hi. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# source.spm:   0%|          | 0.00/812k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# C:\Users\Prachi Shedge\AppData\Roaming\Python\Python312\site-packages\transformers\models\marian\tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# pytorch_model.bin:   0%|          | 0.00/306M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# यह एक सरल मशीन अनुवाद प्रणाली है.
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/306M [00:00<?, ?B/s]
